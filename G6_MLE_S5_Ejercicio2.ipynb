# %%
#pip install seaborn

# %%
import pandas as pd
from pycaret.classification import *
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Cargar y explorar la data
df = pd.read_csv('caso2_microcredito_default.csv')

# 2. Análisis exploratorio NO trivial: identificar patrones por zona
sns.barplot(x='zona', y='default', data=df)
plt.title("Tasa de default por zona")
plt.show()

# 3. Segmentar por negocios donde el default es mayor
df_seg = df[df['tipo_negocio'].isin(['Agrícola', 'Comercio'])]

# 4. Configurar PyCaret con enfoque segmentado
exp = setup(data=df_seg,
            target='default',
            session_id=999,
            categorical_features=['zona', 'tipo_negocio'],
            ignore_features=['cuotas_pagadas'],
            remove_multicollinearity=True,
            multicollinearity_threshold=0.8,
            normalize=True)

# 5. Buscar el mejor modelo considerando AUC y Recall
best = compare_models(sort='Recall')

# 6. Evaluación de sensibilidad para reducir falsos negativos
final_model = tune_model(best, optimize='Recall')
plot_model(final_model, plot='confusion_matrix')
plot_model(final_model, plot='feature')

# 7. Interpretación por zona
interpret_model(final_model, plot='summary')

# 8. Simular nuevo crédito (no usar todo el df)
nuevo_cliente = pd.DataFrame({
    'zona': ['Selva'],
    'tipo_negocio': ['Agrícola'],
    'monto_credito': [4500],
    'mujer_emprendedora': [1],
    'hijos': [3]
})
pred = predict_model(final_model, data=nuevo_cliente)
print(pred)

# 9. Guardar para pipeline rural
save_model(final_model, 'modelo_default_rural_selva')
# Out:
# <style type="text/css">
# #T_13561_row10_col1, #T_13561_row16_col1, #T_13561_row18_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_13561">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13561_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_13561_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13561_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13561_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_13561_row0_col1" class="data row0 col1" >999</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13561_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_13561_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13561_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_13561_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13561_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_13561_row3_col1" class="data row3 col1" >(144, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13561_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_13561_row4_col1" class="data row4 col1" >(144, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13561_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_13561_row5_col1" class="data row5 col1" >(100, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13561_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_13561_row6_col1" class="data row6 col1" >(44, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13561_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_13561_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13561_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_13561_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13561_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_13561_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_13561_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_13561_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_13561_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_13561_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_13561_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_13561_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_13561_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_13561_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_13561_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_13561_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_13561_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_13561_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_13561_row16_col0" class="data row16 col0" >Remove multicollinearity</td>
#       <td id="T_13561_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_13561_row17_col0" class="data row17 col0" >Multicollinearity threshold</td>
#       <td id="T_13561_row17_col1" class="data row17 col1" >0.800000</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_13561_row18_col0" class="data row18 col0" >Normalize</td>
#       <td id="T_13561_row18_col1" class="data row18 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_13561_row19_col0" class="data row19 col0" >Normalize method</td>
#       <td id="T_13561_row19_col1" class="data row19 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_13561_row20_col0" class="data row20 col0" >Fold Generator</td>
#       <td id="T_13561_row20_col1" class="data row20 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_13561_row21_col0" class="data row21 col0" >Fold Number</td>
#       <td id="T_13561_row21_col1" class="data row21 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_13561_row22_col0" class="data row22 col0" >CPU Jobs</td>
#       <td id="T_13561_row22_col1" class="data row22 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_13561_row23_col0" class="data row23 col0" >Use GPU</td>
#       <td id="T_13561_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_13561_row24_col0" class="data row24 col0" >Log Experiment</td>
#       <td id="T_13561_row24_col1" class="data row24 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_13561_row25_col0" class="data row25 col0" >Experiment Name</td>
#       <td id="T_13561_row25_col1" class="data row25 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_13561_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_13561_row26_col0" class="data row26 col0" >USI</td>
#       <td id="T_13561_row26_col1" class="data row26 col1" >3288</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d7c22 th {
#   text-align: left;
# }
# #T_d7c22_row0_col0, #T_d7c22_row0_col1, #T_d7c22_row0_col2, #T_d7c22_row1_col0, #T_d7c22_row1_col1, #T_d7c22_row1_col2, #T_d7c22_row1_col4, #T_d7c22_row1_col5, #T_d7c22_row1_col6, #T_d7c22_row1_col7, #T_d7c22_row2_col0, #T_d7c22_row2_col2, #T_d7c22_row2_col3, #T_d7c22_row2_col4, #T_d7c22_row2_col5, #T_d7c22_row2_col6, #T_d7c22_row2_col7, #T_d7c22_row3_col0, #T_d7c22_row3_col1, #T_d7c22_row3_col2, #T_d7c22_row3_col3, #T_d7c22_row3_col4, #T_d7c22_row3_col5, #T_d7c22_row3_col6, #T_d7c22_row3_col7, #T_d7c22_row4_col0, #T_d7c22_row4_col1, #T_d7c22_row4_col2, #T_d7c22_row4_col3, #T_d7c22_row4_col4, #T_d7c22_row4_col5, #T_d7c22_row4_col6, #T_d7c22_row4_col7, #T_d7c22_row5_col0, #T_d7c22_row5_col1, #T_d7c22_row5_col2, #T_d7c22_row
row6_col3" class="data row6 col3" >1.0000</td>
#       <td id="T_cfcbe_row6_col4" class="data row6 col4" >1.0000</td>
#       <td id="T_cfcbe_row6_col5" class="data row6 col5" >1.0000</td>
#       <td id="T_cfcbe_row6_col6" class="data row6 col6" >1.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cfcbe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cfcbe_row7_col0" class="data row7 col0" >0.9000</td>
#       <td id="T_cfcbe_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_cfcbe_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_cfcbe_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_cfcbe_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_cfcbe_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_cfcbe_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_cfcbe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cfcbe_row8_col0" class="data row8 col0" >0.8000</td>
#       <td id="T_cfcbe_row8_col1" class="data row8 col1" >0.8889</td>
#       <td id="T_cfcbe_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_cfcbe_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_cfcbe_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_cfcbe_row8_col5" class="data row8 col5" >-0.1111</td>
#       <td id="T_cfcbe_row8_col6" class="data row8 col6" >-0.1111</td>
#     </tr>
#     <tr>
#       <th id="T_cfcbe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cfcbe_row9_col0" class="data row9 col0" >0.7000</td>
#       <td id="T_cfcbe_row9_col1" class="data row9 col1" >0.7778</td>
#       <td id="T_cfcbe_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_cfcbe_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_cfcbe_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_cfcbe_row9_col5" class="data row9 col5" >-0.1538</td>
#       <td id="T_cfcbe_row9_col6" class="data row9 col6" >-0.1667</td>
#     </tr>
#     <tr>
#       <th id="T_cfcbe_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cfcbe_row10_col0" class="data row10 col0" >0.8800</td>
#       <td id="T_cfcbe_row10_col1" class="data row10 col1" >0.6444</td>
#       <td id="T_cfcbe_row10_col2" class="data row10 col2" >0.3000</td>
#       <td id="T_cfcbe_row10_col3" class="data row10 col3" >0.2500</td>
#       <td id="T_cfcbe_row10_col4" class="data row10 col4" >0.2667</td>
#       <td id="T_cfcbe_row10_col5" class="data row10 col5" >nan</td>
#       <td id="T_cfcbe_row10_col6" class="data row10 col6" >0.2222</td>
#     </tr>
#     <tr>
#       <th id="T_cfcbe_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_cfcbe_row11_col0" class="data row11 col0" >0.1077</td>
#       <td id="T_cfcbe_row11_col1" class="data row11 col1" >0.3055</td>
#       <td id="T_cfcbe_row11_col2" class="data row11 col2" >0.4583</td>
#       <td id="T_cfcbe_row11_col3" class="data row11 col3" >0.4031</td>
#       <td id="T_cfcbe_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 36
#      33 plot_model(final_model, plot='feature')
#      35 # 7. Interpretación por zona
# ---> 36 interpret_model(final_model, plot='summary')
#      38 # 8. Simular nuevo crédito (no usar todo el df)
#      39 nuevo_cliente = pd.DataFrame({
#      40     'zona': ['Selva'],
#      41     'tipo_negocio': ['Agrícola'],
#    (...)     44     'hijos': [3]
#      45 })
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\utils\generic.py:964, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     962     if globals_d[name] is None:
#     963         raise ValueError(message)
# --> 964 return func(*args, **kwargs)
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\classification\functional.py:1905, in interpret_model(estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    1807 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1808 def interpret_model(
#    1809     estimator,
#    (...)   1817     **kwargs,
#    1818 ):
#    1819     """
#    1820     This function takes a trained model object and returns an interpretation plot
#    1821     based on the test / hold-out set.
#    (...)   1902
#    1903     """
# -> 1905     return _CURRENT_EXPERIMENT.interpret_model(
#    1906         estimator=estimator,
#    1907         plot=plot,
#    1908         feature=feature,
#    1909         observation=observation,
#    1910         use_train_data=use_train_data,
#    1911         X_new_sample=X_new_sample,
#    1912         y_new_sample=y_new_sample,
#    1913         save=save,
#    1914         **kwargs,
#    1915     )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\classification\oop.py:2249, in ClassificationExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    2151 def interpret_model(
#    2152     self,
#    2153     estimator,
#    (...)   2161     **kwargs,
#    2162 ):
#    2163     """
#    2164     This function takes a trained model object and returns an interpretation plot
#    2165     based on the test / hold-out set.
#    (...)   2246
#    2247     """
# -> 2249     return super().interpret_model(
#    2250         estimator=estimator,
#    2251         plot=plot,
#    2252         feature=feature,
#    2253         observation=observation,
#    2254         use_train_data=use_train_data,
#    2255         X_new_sample=X_new_sample,
#    2256         y_new_sample=y_new_sample,
#    2257         save=save,
#    2258         **kwargs,
#    2259     )
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4051, in _SupervisedExperiment.interpret_model(self, estimator, plot, feature, observation, use_train_data, X_new_sample, y_new_sample, save, **kwargs)
#    4049 # checking if shap available
#    4050 if plot in ["summary", "correlation", "reason"]:
# -> 4051     _check_soft_dependencies("shap", extra="analysis", severity="error")
#    4052     import shap
#    4054 # checking if pdpbox is available
#
# File c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\pycaret\utils\_dependencies.py:152, in _check_soft_dependencies(package, severity, extra, install_name)
#     150 if severity == "error":
#     151     logger.exception(f"{msg}")
# --> 152     raise ModuleNotFoundError(msg)
#     153 elif severity == "warning":
#     154     logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'shap' is a soft dependency and not included in the pycaret installation. Please run: `pip install shap` to install.
# Alternately, you can install this by running `pip install pycaret[analysis]`
